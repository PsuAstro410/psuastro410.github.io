# %% [markdown]
# # Lecture 1
#
# In today's lecture, we discuss the main logistics of this course. All information will be available on the course website:
#
# https://psuastro410.github.io/
#
# To download this jupyter notebook on Roar collab, go to RC Shell Access, make a `lectures` directory with `mkdir lectures`, enter the lectures directory with `ls lectures`, and then enter the command\
# `curl -O https://raw.githubusercontent.com/PsuAstro410/psuastro410.github.io/main/lectures/lec1.ipynb`\
#
# To accept this assignment on Classroom 50 with your GitHub profile enrolled in the class, click on the link\
# [https://classroom50.org/PsuAstro410/410astro26/assignments/lecture-1/accept](https://classroom50.org/PsuAstro410/410astro26/assignments/lecture-1/accept)
# and follow the steps the webpage prompts.
#
# To submit this assignment, follow the steps in "First time Classroom 50 setup" and "Accepting and Submitting Assignments" on the course webpage:
# [https://psuastro410.github.io/tips/github/](https://psuastro410.github.io/tips/github/)
#
# ## Syllabus
#
# The couse syllabus is available here:
#
# https://psuastro410.github.io/syllabus/
#
# ## Roar Collab
#
# We will make heavy use of Roar Collab, Penn States High Performance Computing Cluster. **Everyone is required to request an account by the end of today**, so that I can allocate computational resources to everyone.
#
# A walkthrough of how to create an account, and log onto a Roar interactive session, is available here:
#
# https://psuastro410.github.io/tips/roar/
#
# Save your homework assignments **only on your private Home or Work directories**. Do not work in the Scratch or Group directories.
#
# We will now demonstrate what logging onto a Roar session actually looks like...
#
# **Note** Upon starting a new session, you will always need to load any modules you need for your particular session. Use commands
# - `module load python`
# - `module load anaconda`
# - `module load anaconda3`
# - `module load firefox`
#
# etc., to load what you need during a particular session
#
# ## To submit assignments, we will use GitHub
#
# GitHub is a cloud-based developer platform that allows software engineers, data scientists, and creators to store, manage, track, and collaborate on their code. A major advantage of GitHub is that it allows for
#
# ### Version Control
#
# When we develop code, we are going to be making lots of changes over time. And you will find yourself in the following situations:
# - You swear that the code worked perfectly 6 months ago but today it doesn’t and you can’t figure out what changed.
# - The code looks different than you remembered and you don’t know why it changed.
# - Your research group is all working on the same code and you need to sync up with everyone’s changes and make sure that no one breaks the code.
#
# This is what version control does for us. Logs tell you what changes have been made to each file over time. You can request the source as it was at any time in the past. Multiple developers can all work on the same source code and share and synchronize changes. Changes by different developers to the same file are merged. If two developers changed the same part of a file, version control provides mechanisms to resolve conflicts. You can make a branch and work on new features without breaking the current working code, and when you are ready, merge those changes into the main version.
#
# Tip: Even for a single developer, version control is a great asset. For instance, you notice your code is giving different answers than you’ve seen in the past. With version control, you can checkout an old copy when you know it was working, and ask for the difference with the current code.
#
# We will discuss more how to use version control when collaborating, when we discuss course projects. For now, we will use GitHub to document and submit our lecture notes and homework problems.
#
# ## GitHub and Classroom 50
#
# All assignments will be submitted using Classroom 50, which is based on GitHub, but the interface makes sure your assignments are only visible to yourself and the graders (the TA and instructor).
#
# To use Classroom 50, everyone is required to have a personal GitHub account:
#
# https://docs.github.com/en/account-and-profile/how-tos/account-management/creating-an-account-on-github
#
# **Everyone is required to create a personal GitHub account by the end of today, and be added to the Astro 410 Organization**
#
# Your first assignment submission (lecture 1) will be graded as a part of your first homework assignment. To accept an assignment from Classroom 50 from the web, follow the instructions below:
#
# [Web Guide](https://github.com/foundation50/classroom50/wiki/Web-Student-Guide)
#
# To accept and submit an assignment using Git, follow the instructions listed here:
#
# [Git Submission Instructions](
#
# A few notes on submitting assignments
# - Make sure when working on an assignment on your own personal Roar account, you save often. Your connection can get timed out or disconnected, so frequent saving ensures that none of your work is lost
# - Committing your assignments often makes sure that you can keep track of what you changed in your homework assignment
# - Only submit/push your assignment when you are ready for it to be graded.
#
# ## In-Class Exercises
#
# After every lecture, all students will submit Jupyter Notebooks containing the day's lecture materials, as well as that day's in-class exercises. Because today we are just trying to stay afloat with all this technological infostructure I threw your way, we will not have a very difficult exercise...

# %% [markdown]
# ## Exercise 1
#
# Using the python `print()` command, print "We are Penn State!"
