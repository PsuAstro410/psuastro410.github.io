# %% [markdown]
# # Astro 410: Computational Astrophysics — Homework Set 1 (10 pt)
# ## Introduction to GitHub and Python: object types and plotting
#
# **Instructions:** Read the descriptor for each problem, then write your solution code in the Jupyter code cell. Once you are done, add your homework 1 assignment to the list of things to push with `git add HW1.ipynb`, commit your changes with the command `git commit -m "Completed HW 1"`, then push/submit to the instructor/TA using `git push`.
#
# **NOTE:** If you do not also run the git commands described in the website tips (see link in problem 1), *your assignment will not be submitted*.

# %% [markdown]
# ## 1 - Submit lecture 1 (4 pt)
#
# It is a lot of work to get all the infustructure for this course up and running. For the first problem, you get full credit for submitting the first lecture notes using Roar Collab, using the instructions listed here:
#
# https://psuastro410.github.io/tips/github/
#
# Note that the second lecture notes are not a part of this problem, and need to be submitted separately, for credit under "class participation"

# %% [markdown]
# ## 2 - Creating Python Lists with different data types (3 pt)
#
# We will start by creating a number of different lists, each with different data to plot.

# %% [markdown]
# ### 2(a): Create lists of integers with `range()` function. (1 pt)
#
# How to use the `range()` function is listed here:
#
# https://cs.stanford.edu/people/nick/py/python-range.html
#
# Use the `range()` and `list()` functions to create four lists:
# - `x_list_1`, a list of 10 integers, $0, 1, 2, \dots, 8,9$
# - `x_list_2`, a list of 100 integers, $0, 1, 2, \dots, 98, 99$
# - `x_list_3`, a list of 10 integers, $10, 11, 12, \dots, 18, 19$
# - `x_list_4`, a list of 20 integers, $0, 5, 10, \dots, 90, 95$.
#
# After creating, print the contents of each list using the `print()` command:
#
# https://cs.stanford.edu/people/nick/py/python-print.html

# %%
# SOLUTIONS TO 1(A) HERE, IN CELL BELOW

# %% [markdown]
# ### 1(b): Create lists of floats through loops (1 pt)
#
# Some tips for looping are listed below:
#
# https://cs.stanford.edu/people/nick/py/python-for.html
#
# and tips on appending are listed below:
#
# https://www.geeksforgeeks.org/python/append-element-to-an-empty-list-in-python/
#
# Initialize four empty lists `y_list_1`, `y_list_2`, `y_list_3`, and `y_list_4`. Write a for loop on the four `x_list_i` you created in 1(a), and append the four new lists `y_list_i`, by performing arithmetic operations on the elements of `x_list_i`. Each list will be comprised of different floats:
# - `y_list_1` will be the floats $0.0, 1.0, 2.0, \dots, 8.0, 9.0$, created by looping through `x_list_1`
# - `y_list_2` will be the floats $0.0, 0.1, 0.2, \dots, 9.8, 9.9$, created by looping through `x_list_2`
# - `y_list_3` will be the floats $1.0, 1.1, 1.2, \dots, 1.8, 1.9$, created by looping through `x_list_3`
# - `y_list_4` will be the floats $0.0, 2.5, 5.0, \dots, 45.0, 47.5$, created by looping through `x_list_4`
#
# After creating, print their contents using the `print()` function

# %%
# SOLUTIONS TO 1(B) HERE, IN CELL BELOW

# %% [markdown]
# ### 1(c): Create a list of strings (1 pt)
#
# Create a list of strings `str_list`, composed of strings "list 1", "list 2", "list 3", and "list 4". Print their contents

# %%
# SOLUTIONS TO 1(C) HERE, IN CELL BELOW

# %% [markdown]
# ## 2 - Plotting results (3 pt)
#
# ### 2(a): Create a list of lists (1 pt)
#
# Create two lists `x_list` and `y_list`, composed of `x_list_1`, `x_list_2`, etc., and `y_list_1`, `y_list_2`, etc. Print `x_list` and `y_list`.

# %%
# SOLUTIONS TO 2(A) HERE, IN CELL BELOW

# %% [markdown]
# ### 2(b): Plot results using matplotlib module (2 pt)
#
# Use the standard `import matplotlib.pyplot as plt` line to import the matplotlib module. Initialize `fig` and `ax` using the tuple `fig, ax`, and set these equal to `plt.subplots()`.
#
# Use `ax.plot` to plot the four `y_list[i]`, as functions of `x_list[i]`, looping through the lists using a for loop. Plot each as circles using the argument `marker='o'`, and make sure there are no connecting lines using the argument `ls=''`. Set the label for each plot using the argument `label=str_list[i]`. Display the legend using `ax.legend()`, and set the x and y labels using `ax.set_xlabel("x")` and `ax.set_ylabel("y")`. Display with `plt.show()` at the end of the cell.
#
# See documentation below if there are any issues:
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
# SOLUTIONS TO 2(A) HERE, IN CELL BELOW
